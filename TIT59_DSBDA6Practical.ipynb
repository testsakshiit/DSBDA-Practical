# %%
import numpy as np
import pandas as pd

# %%
Air =  pd.read_csv("air_quality_health_impact_data.csv")

# %%
Air.shape
# Out:
# (5811, 15)

# %%
Air
# Out:
#       RecordID         AQI        PM10       PM2_5         NO2        SO2  \
# 0            1  187.270059  295.853039   13.038560    6.639263  66.161150
# 1            2  475.357153  246.254703    9.984497   16.318326  90.499523
# 2            3  365.996971   84.443191   23.111340   96.317811  17.875850
# 3            4  299.329242   21.020609   14.273403   81.234403  48.323616
# 4            5   78.009320   16.987667  152.111623  121.235461  90.866167
# ...        ...         ...         ...         ...         ...        ...
# 5806      5807  171.112762   11.246387  197.984628  158.643107  17.743678
# 5807      5808  490.691667  275.340762   55.774170  132.336871  29.334724
# 5808      5809  314.841798   41.892699  184.708551   82.105823  68.334578
# 5809      5810  208.080473  165.533785  199.177255  100.796385  87.586488
# 5810      5811   83.269257   82.216262  119.968244  193.440691  79.849177
#
#               O3  Temperature   Humidity  WindSpeed  RespiratoryCases  \
# ...

# %%
Air.describe()
# Out:
#           RecordID          AQI         PM10        PM2_5          NO2  \
# count  5811.000000  5811.000000  5811.000000  5811.000000  5811.000000
# mean   2906.000000   248.438476   148.654997   100.223714   102.293445
# std    1677.635538   144.777638    85.698500    58.096612    57.713175
# min       1.000000     0.005817     0.015848     0.031549     0.009625
# 25%    1453.500000   122.951293    75.374954    49.435171    53.538538
# 50%    2906.000000   249.127841   147.634997   100.506337   102.987736
# 75%    4358.500000   373.630668   222.436759   151.340260   151.658516
# max    5811.000000   499.858837   299.901962   199.984965   199.980195
#
#                SO2           O3  Temperature     Humidity    WindSpeed  \
# count  5811.000000  5811.000000  5811.000000  5811.000000  5811.000000
# mean     49.456838   149.312431    14.975500    54.776853     9.989177
# std      28.530329    86.534240    14.483067    26.020786     5.776950
# ...

# %%
Air.count()
# Out:
# RecordID               5811
# AQI                    5811
# PM10                   5811
# PM2_5                  5811
# NO2                    5811
# SO2                    5811
# O3                     5811
# Temperature            5811
# Humidity               5811
# WindSpeed              5811
# RespiratoryCases       5811
# CardiovascularCases    5811
# HospitalAdmissions     5811
# HealthImpactScore      5811
# HealthImpactClass      5811
# dtype: int64

# %%
Air.isnull().sum()
# Out:
# RecordID               0
# AQI                    0
# PM10                   0
# PM2_5                  0
# NO2                    0
# SO2                    0
# O3                     0
# Temperature            0
# Humidity               0
# WindSpeed              0
# RespiratoryCases       0
# CardiovascularCases    0
# HospitalAdmissions     0
# HealthImpactScore      0
# HealthImpactClass      0
# dtype: int64

# %%
Air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5811 entries, 0 to 5810
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   RecordID             5811 non-null   int64
#  1   AQI                  5811 non-null   float64
#  2   PM10                 5811 non-null   float64
#  3   PM2_5                5811 non-null   float64
#  4   NO2                  5811 non-null   float64
#  5   SO2                  5811 non-null   float64
#  6   O3                   5811 non-null   float64
#  7   Temperature          5811 non-null   float64
#  8   Humidity             5811 non-null   float64
#  9   WindSpeed            5811 non-null   float64
#  10  RespiratoryCases     5811 non-null   int64
#  11  CardiovascularCases  5811 non-null   int64
#  12  HospitalAdmissions   5811 non-null   int64
#  13  HealthImpactScore    5811 non-null   float64
#  14  HealthImpactClass    5811 non-null   float64
# ...

# %%
A=Air.dropna()

# %%
A.shape
# Out:
# (5811, 15)

# %%
A=Air.fillna(0)

# %%
A = Air.ffill()

# %%
A = Air.bfill()

# %%
A = Air['O3'].replace(np.NaN, Air['O3'].mean())

# %%
A=Air ['O3'].replace(np.NaN,Air['O3'].median())

# %%
from sklearn.impute import SimpleImputer

# %%
imp = SimpleImputer(missing_values=np.NAN, strategy='mean')

# %%
A= imp.fit_transform(Air)

# %%
A
# Out:
# array([[1.00000000e+00, 1.87270059e+02, 2.95853039e+02, ...,
#         1.00000000e+00, 9.72440411e+01, 0.00000000e+00],
#        [2.00000000e+00, 4.75357153e+02, 2.46254703e+02, ...,
#         0.00000000e+00, 1.00000000e+02, 0.00000000e+00],
#        [3.00000000e+00, 3.65996971e+02, 8.44431907e+01, ...,
#         0.00000000e+00, 1.00000000e+02, 0.00000000e+00],
#        ...,
#        [5.80900000e+03, 3.14841798e+02, 4.18926991e+01, ...,
#         3.00000000e+00, 1.00000000e+02, 1.00000000e+00],
#        [5.81000000e+03, 2.08080473e+02, 1.65533785e+02, ...,
#         3.00000000e+00, 1.00000000e+02, 4.00000000e+00],
#        [5.81100000e+03, 8.32692567e+01, 8.22162622e+01, ...,
#         2.00000000e+00, 8.16682981e+01, 0.00000000e+00]])

# %%
imp = SimpleImputer(missing_values=np.NAN, strategy='most_frequent')

# %%
A= imp.fit_transform(Air)

# %%
A
# Out:
# array([[1.00000000e+00, 1.87270059e+02, 2.95853039e+02, ...,
#         1.00000000e+00, 9.72440411e+01, 0.00000000e+00],
#        [2.00000000e+00, 4.75357153e+02, 2.46254703e+02, ...,
#         0.00000000e+00, 1.00000000e+02, 0.00000000e+00],
#        [3.00000000e+00, 3.65996971e+02, 8.44431907e+01, ...,
#         0.00000000e+00, 1.00000000e+02, 0.00000000e+00],
#        ...,
#        [5.80900000e+03, 3.14841798e+02, 4.18926991e+01, ...,
#         3.00000000e+00, 1.00000000e+02, 1.00000000e+00],
#        [5.81000000e+03, 2.08080473e+02, 1.65533785e+02, ...,
#         3.00000000e+00, 1.00000000e+02, 4.00000000e+00],
#        [5.81100000e+03, 8.32692567e+01, 8.22162622e+01, ...,
#         2.00000000e+00, 8.16682981e+01, 0.00000000e+00]])

# %%
A = pd.DataFrame(A, columns=Air.columns)

# %%
A.head()
# Out:
#    RecordID         AQI        PM10       PM2_5         NO2        SO2  \
# 0       1.0  187.270059  295.853039   13.038560    6.639263  66.161150
# 1       2.0  475.357153  246.254703    9.984497   16.318326  90.499523
# 2       3.0  365.996971   84.443191   23.111340   96.317811  17.875850
# 3       4.0  299.329242   21.020609   14.273403   81.234403  48.323616
# 4       5.0   78.009320   16.987667  152.111623  121.235461  90.866167
#
#            O3  Temperature   Humidity  WindSpeed  RespiratoryCases  \
# 0   54.624280     5.150335  84.424344   6.137755               7.0
# 1  169.621728     1.543378  46.851415   4.521422              10.0
# 2    9.006794     1.169483  17.806977  11.157384              13.0
# 3   93.161033    21.925276  99.473373  15.302500               8.0
# 4  241.795138     9.217517  24.906837  14.534733               9.0
#
#    CardiovascularCases  HospitalAdmissions  HealthImpactScore  \
# 0                  5.0                 1.0          97.244041
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
len(A)
# Out:
# 5811

# %%
train,test =train_test_split(A)

# %%
len(train)
# Out:
# 4358

# %%
len(test)
# Out:
# 1453

# %%
train.head()
# Out:
#       RecordID         AQI       PM10       PM2_5         NO2        SO2  \
# 482      483.0  227.270532  95.916255   60.355845   42.190544  39.756601
# 107      108.0  377.775569  85.621221   20.774758  103.729258  56.069782
# 82        83.0  165.449012  57.694732   29.677076  188.244327  81.769931
# 5019    5020.0  428.967457  68.682701   57.991664   76.863527  19.875248
# 5796    5797.0   67.872927  50.130026  107.005843   15.806535  78.006274
#
#               O3  Temperature   Humidity  WindSpeed  RespiratoryCases  \
# 482    93.639146    -9.101133  16.645147  14.859381              13.0
# 107   210.404533    13.023223  63.501211   6.246615              15.0
# 82     62.502709    26.683055  58.406134  14.195940              13.0
# 5019  274.878365     7.298661  89.710770  17.035277              13.0
# 5796  163.591252     0.874165  90.978257  15.428506              10.0
#
#       CardiovascularCases  HospitalAdmissions  HealthImpactScore  \
# ...

# %%
test.head()
# Out:
#       RecordID         AQI        PM10       PM2_5         NO2        SO2  \
# 5306    5307.0  238.491696  158.641565   12.644868  173.840018  82.323644
# 2440    2441.0  276.855743  293.551790  102.865296   86.800003  32.791955
# 5455    5456.0  108.726466  202.259812   74.794052  145.347826  82.917348
# 3170    3171.0  327.586857  194.608513  125.913479  137.868173  39.514801
# 2475    2476.0  434.984580  132.382301  194.921842  174.048332  78.738331
#
#               O3  Temperature   Humidity  WindSpeed  RespiratoryCases  \
# 5306  101.050753    -5.175645  67.477708   2.956089               9.0
# 2440  243.312883     9.791243  57.809912  10.372847              10.0
# 5455   64.503891    -9.600906  98.821361  10.616147               2.0
# 3170  150.720102    34.605732  21.478391   5.329268              10.0
# 2475  103.667626    39.850871  84.097229  13.317864               8.0
#
#       CardiovascularCases  HospitalAdmissions  HealthImpactScore  \
# ...

# %%
train , test =train_test_split(A,test_size=0.20)

# %%
len(train)
# Out:
# 4648

# %%
len(test)
# Out:
# 1163

# %%
A.describe()
# Out:
#           RecordID          AQI         PM10        PM2_5          NO2  \
# count  5811.000000  5811.000000  5811.000000  5811.000000  5811.000000
# mean   2906.000000   248.438476   148.654997   100.223714   102.293445
# std    1677.635538   144.777638    85.698500    58.096612    57.713175
# min       1.000000     0.005817     0.015848     0.031549     0.009625
# 25%    1453.500000   122.951293    75.374954    49.435171    53.538538
# 50%    2906.000000   249.127841   147.634997   100.506337   102.987736
# 75%    4358.500000   373.630668   222.436759   151.340260   151.658516
# max    5811.000000   499.858837   299.901962   199.984965   199.980195
#
#                SO2           O3  Temperature     Humidity    WindSpeed  \
# count  5811.000000  5811.000000  5811.000000  5811.000000  5811.000000
# mean     49.456838   149.312431    14.975500    54.776853     9.989177
# std      28.530329    86.534240    14.483067    26.020786     5.776950
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
B=scaler.fit_transform(A)

# %%
pd.DataFrame(B).describe()
# Out:
#                 0             1             2             3             4   \
# count  5811.000000  5.811000e+03  5.811000e+03  5.811000e+03  5.811000e+03
# mean      0.000000  8.559283e-18  4.891019e-18 -1.858587e-16 -2.347689e-16
# std       1.000086  1.000086e+00  1.000086e+00  1.000086e+00  1.000086e+00
# min      -1.731753 -1.716108e+00 -1.734592e+00 -1.724727e+00 -1.772431e+00
# 25%      -0.865876 -8.668326e-01 -8.551649e-01 -8.742836e-01 -8.448522e-01
# 50%       0.000000  4.761952e-03 -1.190321e-02  4.865131e-03  1.203105e-02
# 75%       0.865876  8.647949e-01  8.610199e-01  8.799299e-01  8.554254e-01
# max       1.731753  1.736746e+00  1.765025e+00  1.717309e+00  1.692770e+00
#
#                  5             6             7             8             9   \
# count  5.811000e+03  5.811000e+03  5.811000e+03  5.811000e+03  5.811000e+03
# mean   1.797449e-16  4.279641e-17  1.039341e-17  3.851677e-17 -2.200958e-17
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
B=scaler.fit_transform(A)

# %%
pd.DataFrame(B).describe()
# Out:
#                0            1            2            3            4   \
# count  5811.00000  5811.000000  5811.000000  5811.000000  5811.000000
# mean      0.50000     0.497011     0.495652     0.501078     0.511494
# std       0.28875     0.289640     0.285770     0.290551     0.288608
# min       0.00000     0.000000     0.000000     0.000000     0.000000
# 25%       0.25000     0.245963     0.251292     0.247076     0.267684
# 50%       0.50000     0.498391     0.492251     0.502491     0.514966
# 75%       0.75000     0.747469     0.741685     0.756720     0.758356
# max       1.00000     1.000000     1.000000     1.000000     1.000000
#
#                 5            6            7            8            9   \
# count  5811.000000  5811.000000  5811.000000  5811.000000  5811.000000
# mean      0.494663     0.497810     0.499785     0.497526     0.499428
# std       0.285422     0.288510     0.289926     0.289133     0.288890
# ...

# %%
B=pd.DataFrame(B).describe()

# %%
from sklearn.preprocessing import Binarizer
bin=Binarizer(threshold=0.5)

# %%
B=bin.fit_transform(B)
pd.DataFrame(B).describe()
# Out:
#              0         1         2         3         4         5         6   \
# count  8.000000  8.000000  8.000000  8.000000  8.000000  8.000000  8.000000
# mean   0.375000  0.375000  0.375000  0.625000  0.625000  0.375000  0.375000
# std    0.517549  0.517549  0.517549  0.517549  0.517549  0.517549  0.517549
# min    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 25%    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 50%    0.000000  0.000000  0.000000  1.000000  1.000000  0.000000  0.000000
# 75%    1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# max    1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
#
#              7         8         9        10       11       12       13  \
# count  8.000000  8.000000  8.000000  8.00000  8.00000  8.00000  8.00000
# mean   0.375000  0.375000  0.500000  0.25000  0.25000  0.25000  0.75000
# ...

# %%
data=pd.read_csv('table_data.csv')

# %%
data
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()  
B=le.fit_transform(data['Country'])
pd.DataFrame(B).describe()
# Out:
#               0
# count  6.000000
# mean   2.500000
# std    1.870829
# min    0.000000
# 25%    1.250000
# 50%    2.500000
# 75%    3.750000
# max    5.000000

# %%
B
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy

# %%
B=data[:]

# %%
from sklearn.linear_model import LinearRegression

# %%
x=A['O3'].values

# %%
X =x.reshape(-1,1)

# %%
X
# Out:
# array([[ 54.62427998],
#        [169.62172753],
#        [  9.0067936 ],
#        ...,
#        [105.56850348],
#        [166.46953697],
#        [ 28.68188524]])

# %%
x
# Out:
# array([ 54.62427998, 169.62172753,   9.0067936 , ..., 105.56850348,
#        166.46953697,  28.68188524])

# %%
Y= A['Temperature']

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X, Y)
# Out:
# LinearRegression()

# %%
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
LinearRegression()
# Out:
# LinearRegression()

# %%
score = model.score(X, Y) * 100
print(score)
# Out:
# 0.00015808284271612294

# %%
model.predict([[128]])
# Out:
# array([14.97998442])

# %%
import numpy as np
arr = np.array([94.66002573])
print(arr)
# Out:
# [94.66002573]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X,Y)
